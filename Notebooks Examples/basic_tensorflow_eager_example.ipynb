# %%
import numpy as np
import tensorflow as tf
#tf.enable_eager_execution()  # if we're using tf version 1.14, then we need to call this command; if using 2.0, then eager execution is enabled by default

# %%
#optimizer = tf.train.GradientDescentOptimizer(learning_rate=.2)  # choose our optimizer and learning rate
optimizer = tf.compat.v1.train.GradientDescentOptimizer(learning_rate=.2)  # choose our optimizer and learning rate, use tf 1.0 command
x = tf.Variable(3.0)  # define a variable to optimize, with an initial value of 2

for i in range(150):  # iterative optimization loop
  with tf.GradientTape() as tape:  # gradient tape keeps track of the gradients associated with all the operations
    # define our very simple minimization problem:
    loss = x ** 2 + 1  # we're going to minimize x^2, which occurs at x=0

  # compute and apply gradients:
  gradient = tape.gradient(loss, x)

  # print out current iteration and loss value:
  print(i, 'loss = ' + str(loss.numpy()), 'x = ' + str(x.numpy()))

  optimizer.apply_gradients([(gradient, x)])
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
#
# 0 loss = 9.999998 x = 3.0
# 1 loss = 4.24 x = 1.8000001
# 2 loss = 2.1664002 x = 1.0800002
# 3 loss = 1.4199041 x = 0.6480001
# 4 loss = 1.1511655 x = 0.38880008
# 5 loss = 1.0544196 x = 0.23328006
# 6 loss = 1.0195911 x = 0.13996804
# 7 loss = 1.0070528 x = 0.08398082
# 8 loss = 1.002539 x = 0.050388496
# 9 loss = 1.0009141 x = 0.030233094
# 10 loss = 1.000329 x = 0.018139858
# 11 loss = 1.0001185 x = 0.010883913
# 12 loss = 1.0000427 x = 0.0065303473
# 13 loss = 1.0000154 x = 0.0039182086
# 14 loss = 1.0000055 x = 0.002350925
# 15 loss = 1.000002 x = 0.0014105547
# 16 loss = 1.0000007 x = 0.0008463328
# 17 loss = 1.0000002 x = 0.00050779956
# 18 loss = 1.0000001 x = 0.00030467968
# 19 loss = 1.0 x = 0.00018280781
# 20 loss = 1.0 x = 0.00010968467
# 21 loss = 1.0 x = 6.58108e-05
# 22 loss = 1.0 x = 3.9486466e-05
# 23 loss = 1.0 x = 2.3691873e-05
# 24 loss = 1.0 x = 1.4215121e-05
# 25 loss = 1.0 x = 8.5290685e-06
# 26 loss = 1.0 x = 5.11744e-06
# 27 loss = 1.0 x = 3.0704628e-06
# 28 loss = 1.0 x = 1.8422776e-06
# 29 loss = 1.0 x = 1.1053663e-06
# 30 loss = 1.0 x = 6.632194e-07
# 31 loss = 1.0 x = 3.9793153e-07
# 32 loss = 1.0 x = 2.3875876e-07
# 33 loss = 1.0 x = 1.4325519e-07
# 34 loss = 1.0 x = 8.595311e-08
# 35 loss = 1.0 x = 5.1571856e-08
# 36 loss = 1.0 x = 3.0943095e-08
# 37 loss = 1.0 x = 1.8565851e-08
# 38 loss = 1.0 x = 1.1139503e-08
# 39 loss = 1.0 x = 6.6836985e-09
# 40 loss = 1.0 x = 4.010219e-09
# 41 loss = 1.0 x = 2.4061304e-09
# 42 loss = 1.0 x = 1.4436771e-09
# 43 loss = 1.0 x = 8.662057e-10
# 44 loss = 1.0 x = 5.1972326e-10
# 45 loss = 1.0 x = 3.1183373e-10
# 46 loss = 1.0 x = 1.8710013e-10
# 47 loss = 1.0 x = 1.12259944e-10
# 48 loss = 1.0 x = 6.735595e-11
# 49 loss = 1.0 x = 4.0413537e-11
# 50 loss = 1.0 x = 2.4248088e-11
# 51 loss = 1.0 x = 1.454884e-11
# 52 loss = 1.0 x = 8.729291e-12
# 53 loss = 1.0 x = 5.237569e-12
# 54 loss = 1.0 x = 3.142541e-12
# 55 loss = 1.0 x = 1.8855236e-12
# 56 loss = 1.0 x = 1.1313131e-12
# 57 loss = 1.0 x = 6.7878786e-13
# 58 loss = 1.0 x = 4.0727263e-13
# 59 loss = 1.0 x = 2.4436345e-13
# 60 loss = 1.0 x = 1.466179e-13
# 61 loss = 1.0 x = 8.797072e-14
# 62 loss = 1.0 x = 5.27824e-14
# 63 loss = 1.0 x = 3.1669403e-14
# 64 loss = 1.0 x = 1.9001634e-14
# 65 loss = 1.0 x = 1.140097e-14
# 66 loss = 1.0 x = 6.8405826e-15
# 67 loss = 1.0 x = 4.1043494e-15
# 68 loss = 1.0 x = 2.462609e-15
# 69 loss = 1.0 x = 1.4775644e-15
# 70 loss = 1.0 x = 8.8653745e-16
# 71 loss = 1.0 x = 5.3192213e-16
# 72 loss = 1.0 x = 3.1915288e-16
# 73 loss = 1.0 x = 1.9149164e-16
# 74 loss = 1.0 x = 1.1489487e-16
# 75 loss = 1.0 x = 6.8936915e-17
# 76 loss = 1.0 x = 4.1362134e-17
# 77 loss = 1.0 x = 2.4817261e-17
# 78 loss = 1.0 x = 1.4890335e-17
# 79 loss = 1.0 x = 8.9341925e-18
# 80 loss = 1.0 x = 5.360516e-18
# 81 loss = 1.0 x = 3.2163092e-18
# 82 loss = 1.0 x = 1.9297849e-18
# 2023-02-22 16:19:18.401284: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-02-22 16:19:18.401459: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 83 loss = 1.0 x = 1.1578699e-18
# 84 loss = 1.0 x = 6.9472087e-19
# 85 loss = 1.0 x = 4.168321e-19
# 86 loss = 1.0 x = 2.5009925e-19
# 87 loss = 1.0 x = 1.500595e-19
# 88 loss = 1.0 x = 9.003563e-20
# 89 loss = 1.0 x = 5.40213e-20
# 90 loss = 1.0 x = 3.2412697e-20
# 91 loss = 1.0 x = 1.9447566e-20
# 92 loss = 1.0 x = 1.16685046e-20
# 93 loss = 1.0 x = 7.001079e-21
# 94 loss = 1.0 x = 4.200645e-21
# 95 loss = 1.0 x = 2.5203795e-21
# 96 loss = 1.0 x = 1.5122227e-21
# 97 loss = 1.0 x = 9.073332e-22
# 98 loss = 1.0 x = 5.443985e-22
# 99 loss = 1.0 x = 3.2663817e-22
# 100 loss = 1.0 x = 1.9598227e-22
# 101 loss = 1.0 x = 1.1758934e-22
# 102 loss = 1.0 x = 7.055344e-23
# 103 loss = 1.0 x = 4.2331967e-23
# 104 loss = 1.0 x = 2.5399123e-23
# 105 loss = 1.0 x = 1.523944e-23
# 106 loss = 1.0 x = 9.143645e-24
# 107 loss = 1.0 x = 5.4861766e-24
# 108 loss = 1.0 x = 3.2917006e-24
# 109 loss = 1.0 x = 1.9750182e-24
# 110 loss = 1.0 x = 1.1850106e-24
# 111 loss = 1.0 x = 7.110046e-25
# 112 loss = 1.0 x = 4.2660173e-25
# 113 loss = 1.0 x = 2.559604e-25
# 114 loss = 1.0 x = 1.5357582e-25
# 115 loss = 1.0 x = 9.2145234e-26
# 116 loss = 1.0 x = 5.5286965e-26
# 117 loss = 1.0 x = 3.3172174e-26
# 118 loss = 1.0 x = 1.990326e-26
# 119 loss = 1.0 x = 1.19419305e-26
# 120 loss = 1.0 x = 7.165144e-27
# 121 loss = 1.0 x = 4.299079e-27
# 122 loss = 1.0 x = 2.579444e-27
# 123 loss = 1.0 x = 1.5476654e-27
# 124 loss = 1.0 x = 9.285964e-28
# 125 loss = 1.0 x = 5.571578e-28
# 126 loss = 1.0 x = 3.3429404e-28
# 127 loss = 1.0 x = 2.0057608e-28
# 128 loss = 1.0 x = 1.203455e-28
# 129 loss = 1.0 x = 7.2207266e-29
# 130 loss = 1.0 x = 4.332424e-29
# 131 loss = 1.0 x = 2.5994466e-29
# 132 loss = 1.0 x = 1.5596625e-29
# 133 loss = 1.0 x = 9.357968e-30
# 134 loss = 1.0 x = 5.614763e-30
# 135 loss = 1.0 x = 3.368857e-30
# 136 loss = 1.0 x = 2.0213096e-30
# 137 loss = 1.0 x = 1.212783e-30
# 138 loss = 1.0 x = 7.276682e-31
# 139 loss = 1.0 x = 4.366e-31
# 140 loss = 1.0 x = 2.619595e-31
# 141 loss = 1.0 x = 1.5717546e-31
# 142 loss = 1.0 x = 9.4305175e-32
# 143 loss = 1.0 x = 5.6583096e-32
# 144 loss = 1.0 x = 3.3949781e-32
# 145 loss = 1.0 x = 2.0369824e-32
# 146 loss = 1.0 x = 1.2221869e-32
# 147 loss = 1.0 x = 7.333108e-33
# 148 loss = 1.0 x = 4.3998577e-33
# 149 loss = 1.0 x = 2.6399118e-33
